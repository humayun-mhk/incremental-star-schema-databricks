-- %%
drop table datamodelling.default.source_data

-- %%
create table datamodelling.default.source_data
(
    order_id INT PRIMARY KEY,
    order_date DATE,

    customer_id INT,
    customer_name VARCHAR(100),
    customer_email VARCHAR(100),

    product_id INT,
    product_name VARCHAR(100),
    product_category VARCHAR(50),

    quantity INT,
    unit_price DECIMAL(10, 2),

    payment_type VARCHAR(50),
    country VARCHAR(50),

    last_updated DATE
);

-- %%
INSERT INTO datamodelling.default.source_data (
    order_id, order_date, customer_id, customer_name, customer_email,
    product_id, product_name, product_category,
    quantity, unit_price, payment_type, country, last_updated
)
VALUES
(1, '2025-01-01', 101, 'Ali Khan', 'ali@gmail.com', 201, 'Laptop', 'Electronics', 1, 850.00, 'Credit Card', 'Pakistan', '2025-01-01'),
(2, '2025-01-02', 102, 'Sara Ahmed', 'sara@gmail.com', 202, 'Mouse', 'Electronics', 2, 25.00, 'Cash', 'Pakistan', '2025-01-02'),
(3, '2025-01-03', 103, 'Usman Ali', 'usman@gmail.com', 203, 'Keyboard', 'Electronics', 1, 45.00, 'Debit Card', 'Pakistan', '2025-01-03'),
(4, '2025-01-04', 104, 'Ayesha Noor', 'ayesha@gmail.com', 204, 'Monitor', 'Electronics', 1, 180.00, 'Credit Card', 'Pakistan', '2025-01-04'),
(5, '2025-01-05', 105, 'Hamza Khan', 'hamza@gmail.com', 205, 'Printer', 'Electronics', 1, 120.00, 'Cash', 'Pakistan', '2025-01-05');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
select * from datamodelling.default.source_data
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
INSERT INTO datamodelling.default.source_data (
    order_id, order_date, customer_id, customer_name, customer_email,
    product_id, product_name, product_category,
    quantity, unit_price, payment_type, country, last_updated
)
VALUES
(6, '2025-01-06', 106, 'Zain Malik', 'zain@gmail.com', 206, 'Desk', 'Furniture', 1, 200.00, 'Debit Card', 'Pakistan', '2025-01-06'),
(7, '2025-01-07', 107, 'Hina Shah', 'hina@gmail.com', 207, 'Office Chair', 'Furniture', 2, 75.00, 'Credit Card', 'Pakistan', '2025-01-07');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

-- %%
INSERT INTO datamodelling.default.source_data (
    order_id, order_date, customer_id, customer_name, customer_email,
    product_id, product_name, product_category,
    quantity, unit_price, payment_type, country, last_updated
)
VALUES
(8, '2025-01-08', 108, 'Bilal Ahmad', 'bilal@gmail.com', 208, 'Table Lamp', 'Furniture', 1, 65.00, 'Cash', 'Pakistan', '2025-01-08'),
(9, '2025-01-09', 109, 'Noor Fatima', 'noor@gmail.com', 209, 'Notebook', 'Stationery', 5, 10.00, 'Debit Card', 'Pakistan', '2025-01-09'),
(10, '2025-01-10', 110, 'Imran Sheikh', 'imran@gmail.com', 210, 'Headphones', 'Electronics', 1, 120.00, 'Credit Card', 'Pakistan', '2025-01-10'),
(11, '2025-01-11', 111, 'Maryam Iqbal', 'maryam@gmail.com', 211, 'Backpack', 'Accessories', 1, 90.00, 'Cash', 'Pakistan', '2025-01-11');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>
